# %%
import tensorflow as tf

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
from keras_unet_collection import models, losses
import numpy as np
import timeit

# %%
import time

# Définition des différentes configurations de modèle
model_configs = [
    {
        'name': 'lightest',
        'input_shape': (320, 320, 3),
        'filter_num_down': [32, 32, 32, 32],
        'filter_num_up': [32, 32, 32, 32],
        'filter_mid_num_down': [8, 8, 8, 8],
        'filter_mid_num_up': [8, 8, 8, 8],
        'filter_4f_num': [32, 32]
    },
    {
        'name': 'light',
        'input_shape': (320, 320, 3),
        'filter_num_down': [64, 64, 64, 64],
        'filter_num_up': [64, 64, 64, 64],
        'filter_mid_num_down': [16, 16, 16, 16],
        'filter_mid_num_up': [16, 16, 16, 16],
        'filter_4f_num': [64, 64]
    },
    {
        'name': 'medium',
        'input_shape': (320, 320, 3),
        'filter_num_down': [128, 128, 128, 128],
        'filter_num_up': [128, 128, 128, 128],
        'filter_mid_num_down': [32, 32, 32, 32],
        'filter_mid_num_up': [32, 32, 32, 32],
        'filter_4f_num': [128, 128]
    },
    {
        'name': 'heavy',
        'input_shape': (320, 320, 3),
        'filter_num_down': [256, 256, 256, 256],
        'filter_num_up': [256, 256, 256, 256],
        'filter_mid_num_down': [64, 64, 64, 64],
        'filter_mid_num_up': [64, 64, 64, 64],
        'filter_4f_num': [256, 256]
    },
    {
        'name': 'heaviest',
        'input_shape': (320, 320, 3),
        'filter_num_down': [512, 512, 512, 512],
        'filter_num_up': [512, 512, 512, 512],
        'filter_mid_num_down': [128, 128, 128, 128],
        'filter_mid_num_up': [128, 128, 128, 128],
        'filter_4f_num': [512, 512]
    }
]



data = np.zeros((320,320,3))
input_image =np.expand_dims(data, axis=0) 

for config in model_configs:
    model_name = config['name']
    input_shape = config['input_shape']
    filter_num_down = config['filter_num_down']
    filter_num_up = config['filter_num_up']
    filter_mid_num_down = config['filter_mid_num_down']
    filter_mid_num_up = config['filter_mid_num_up']
    filter_4f_num = config['filter_4f_num']
    
    model = models.u2net_2d(
        input_shape, n_labels=1,
        filter_num_down=filter_num_down,
        filter_num_up=filter_num_up,
        filter_mid_num_down=filter_mid_num_down,
        filter_mid_num_up=filter_mid_num_up,
        filter_4f_num=filter_4f_num,
        activation='ReLU',
        output_activation='Sigmoid',
        batch_norm=True,
        pool='max',
        unpool='bilinear',
        deep_supervision=False,
        name=model_name
    )
    
    inference_time = timeit.timeit(lambda: model.predict(input_image), number=10)
    num_params = model.count_params()
    
    print(f"Modèle: {model_name}")
    print(f"Nombre de paramètres: {num_params}")
    print(f"Temps d'inférence: {inference_time} secondes")
    print("-------------------------")
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of RSU output channels within downsampling blocks: filter_num_down = [32, 32, 32, 32]
# 	Number of RSU intermediate channels within downsampling blocks: filter_mid_num_down = [8, 8, 8, 8]
# 	Number of RSU output channels within upsampling blocks: filter_num_up = [32, 32, 32, 32]
# 	Number of RSU intermediate channels within upsampling blocks: filter_mid_num_up = [8, 8, 8, 8]
# 	Number of RSU-4F output channels within downsampling and bottom blocks: filter_4f_num = [32, 32]
# 	Number of RSU-4F intermediate channels within downsampling and bottom blocks: filter_4f_num = [16, 16]
# ----------
# Explicitly specifying keywords listed above if their "auto" settings do not satisfy your needs
# ----------
# The depth of u2net_2d = len(filter_num_down) + len(filter_4f_num) = 6
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 172ms/step
# Modèle: lightest
# Nombre de paramètres: 345261
# Temps d'inférence: 3.423435299999255 secondes
# -------------------------
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of RSU output channels within downsampling blocks: filter_num_down = [64, 64, 64, 64]
# 	Number of RSU intermediate channels within downsampling blocks: filter_mid_num_down = [16, 16, 16, 16]
# 	Number of RSU output channels within upsampling blocks: filter_num_up = [64, 64, 64, 64]
# 	Number of RSU intermediate channels within upsampling blocks: filter_mid_num_up = [16, 16, 16, 16]
# 	Number of RSU-4F output channels within downsampling and bottom blocks: filter_4f_num = [64, 64]
# 	Number of RSU-4F intermediate channels within downsampling and bottom blocks: filter_4f_num = [32, 32]
# ----------
# Explicitly specifying keywords listed above if their "auto" settings do not satisfy your needs
# ----------
# The depth of u2net_2d = len(filter_num_down) + len(filter_4f_num) = 6
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 329ms/step
# Modèle: light
# Nombre de paramètres: 1363277
# Temps d'inférence: 5.143967800002429 secondes
# -------------------------
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of RSU output channels within downsampling blocks: filter_num_down = [128, 128, 128, 128]
# 	Number of RSU intermediate channels within downsampling blocks: filter_mid_num_down = [32, 32, 32, 32]
# 	Number of RSU output channels within upsampling blocks: filter_num_up = [128, 128, 128, 128]
# 	Number of RSU intermediate channels within upsampling blocks: filter_mid_num_up = [32, 32, 32, 32]
# 	Number of RSU-4F output channels within downsampling and bottom blocks: filter_4f_num = [128, 128]
# 	Number of RSU-4F intermediate channels within downsampling and bottom blocks: filter_4f_num = [64, 64]
# ----------
# Explicitly specifying keywords listed above if their "auto" settings do not satisfy your needs
# ----------
# The depth of u2net_2d = len(filter_num_down) + len(filter_4f_num) = 6
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1000ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Modèle: medium
# Nombre de paramètres: 5417613
# Temps d'inférence: 11.76719199999934 secondes
# -------------------------
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of RSU output channels within downsampling blocks: filter_num_down = [256, 256, 256, 256]
# 	Number of RSU intermediate channels within downsampling blocks: filter_mid_num_down = [64, 64, 64, 64]
# 	Number of RSU output channels within upsampling blocks: filter_num_up = [256, 256, 256, 256]
# 	Number of RSU intermediate channels within upsampling blocks: filter_mid_num_up = [64, 64, 64, 64]
# 	Number of RSU-4F output channels within downsampling and bottom blocks: filter_4f_num = [256, 256]
# 	Number of RSU-4F intermediate channels within downsampling and bottom blocks: filter_4f_num = [128, 128]
# ----------
# Explicitly specifying keywords listed above if their "auto" settings do not satisfy your needs
# ----------
# The depth of u2net_2d = len(filter_num_down) + len(filter_4f_num) = 6
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# Modèle: heavy
# Nombre de paramètres: 21599501
# Temps d'inférence: 36.55065470000045 secondes
# -------------------------
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of RSU output channels within downsampling blocks: filter_num_down = [512, 512, 512, 512]
# 	Number of RSU intermediate channels within downsampling blocks: filter_mid_num_down = [128, 128, 128, 128]
# 	Number of RSU output channels within upsampling blocks: filter_num_up = [512, 512, 512, 512]
# 	Number of RSU intermediate channels within upsampling blocks: filter_mid_num_up = [128, 128, 128, 128]
# 	Number of RSU-4F output channels within downsampling and bottom blocks: filter_4f_num = [512, 512]
# 	Number of RSU-4F intermediate channels within downsampling and bottom blocks: filter_4f_num = [256, 256]
# ----------
# Explicitly specifying keywords listed above if their "auto" settings do not satisfy your needs
# ----------
# The depth of u2net_2d = len(filter_num_down) + len(filter_4f_num) = 6
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 12s 12s/step
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 11s 11s/step
# Modèle: heaviest
# Nombre de paramètres: 86256141
# Temps d'inférence: 107.65952599999946 secondes
# -------------------------
